# %%
import numpy as np
# Out:
# Running cells with 'deepvbh (Python 3.12.12)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/export/home/xiatao/project/xmvb-cpp/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
